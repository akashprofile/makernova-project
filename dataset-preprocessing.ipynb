# %%
import pandas as pd

df = pd.read_csv("./FilteredDataset.csv")

# %%
df.shape
# Out:
# (246945, 330)

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246945 entries, 0 to 246944
# Data columns (total 330 columns):
#  #    Column                                          Dtype
# ---   ------                                          -----
#  0    Unnamed: 0                                      int64
#  1    diseases                                        object
#  2    anxiety and nervousness                         int64
#  3    depression                                      int64
#  4    shortness of breath                             int64
#  5    depressive or psychotic symptoms                int64
#  6    sharp chest pain                                int64
#  7    dizziness                                       int64
#  8    insomnia                                        int64
#  9    abnormal involuntary movements                  int64
#  10   chest tightness                                 int64
#  11   palpitations                                    int64
# ...
